# %%
import torch
import torch.optim as optim
import torch.utils.data as Data
import torch.nn.functional as F
import torch.nn as nn
import numpy as np
from torch.autograd import Variable
import matplotlib.pyplot as plt

# %%
class EEGNET(nn.Module):
    def __init__(self,act=nn.ELU(alpha=1.)):
        super(EEGNET,self).__init__()
        self.firstconv=nn.Sequential(
            nn.Conv2d(1,16,(1,51),(1,1),padding=(0,25),bias=False),
            nn.BatchNorm2d(16,eps=1e-05,momentum=0.1,affine=True,track_running_stats=True)
        )
        self.depthwiseConv=nn.Sequential(
            nn.Conv2d(16,32,(2,1),(1,1),groups=16,bias=False),
            nn.BatchNorm2d(32,eps=1e-05,momentum=0.1,affine=True,track_running_stats=True),
            act,
            nn.AvgPool2d((1,4),stride=(1,4),padding=0),
            nn.Dropout(p=0.5)
        )
        self.separableConv=nn.Sequential(
            nn.Conv2d(32,32,(1,15),(1,1),padding=(0,7),bias=False),
            nn.BatchNorm2d(32,eps=1e-05,momentum=0.1,affine=True,track_running_stats=True),
            act,
            nn.AvgPool2d((1,8),stride=(1,8),padding=0),
            nn.Dropout(p=0.25)
        )
        self.classify=nn.Sequential(
            nn.Linear(in_features=736,out_features=2,bias=True)
        )
    def forward(self,x):
        x=self.firstconv(x)
        x=self.depthwiseConv(x)
        x=self.separableConv(x)
        x=x.view(-1,736)
        x=self.classify(x)
        return x

# %%
class Flatten(nn.Module):
    def forward(self, input):
        return input.view(input.size(0), -1)

class DeepConvNet(nn.Module):
    def __init__(self,act=nn.ELU(alpha=1.),C=2,T=750,N=2):
        super(DeepConvNet,self).__init__()
        self.net=nn.Sequential(
            nn.Conv2d(1,25,(1,5)),
            nn.Conv2d(25,25,(C,1)),
            nn.BatchNorm2d(25,eps=1e-05,momentum=0.1,affine=True,track_running_stats=True),
            act,
            nn.MaxPool2d((1,2),stride=(1,2),padding=0),
            nn.Dropout(p=0.5),
            nn.Conv2d(25,50,(1,5)),
            nn.BatchNorm2d(50,eps=1e-05,momentum=0.1,affine=True,track_running_stats=True),
            act,
            nn.MaxPool2d((1,2),stride=(1,2),padding=0),
            nn.Dropout(p=0.5),
            nn.Conv2d(50,100,(1,5)),
            nn.BatchNorm2d(100,eps=1e-05,momentum=0.1,affine=True,track_running_stats=True),
            act,
            nn.MaxPool2d((1,2),stride=(1,2),padding=0),
            nn.Dropout(p=0.5),
            nn.Conv2d(100,200,(1,5)),
            nn.BatchNorm2d(200,eps=1e-05,momentum=0.1,affine=True,track_running_stats=True),
            act,
            nn.MaxPool2d((1,2),stride=(1,2),padding=0),
            nn.Dropout(p=0.5),
            Flatten(),
            nn.Linear(8600,2)
        )
    def forward(self,x):
        x=self.net(x)
        return x

# %%
def read_bci_data():
    S4b_train = np.load('S4b_train.npz')
    X11b_train = np.load('X11b_train.npz')
    S4b_test = np.load('S4b_test.npz')
    X11b_test = np.load('X11b_test.npz')

    train_data = np.concatenate((S4b_train['signal'], X11b_train['signal']), axis=0)
    train_label = np.concatenate((S4b_train['label'], X11b_train['label']), axis=0)
    test_data = np.concatenate((S4b_test['signal'], X11b_test['signal']), axis=0)
    test_label = np.concatenate((S4b_test['label'], X11b_test['label']), axis=0)

    train_label = train_label - 1
    test_label = test_label -1
    train_data = np.transpose(np.expand_dims(train_data, axis=1), (0, 1, 3, 2))
    test_data = np.transpose(np.expand_dims(test_data, axis=1), (0, 1, 3, 2))

    mask = np.where(np.isnan(train_data))
    train_data[mask] = np.nanmean(train_data)

    mask = np.where(np.isnan(test_data))
    test_data[mask] = np.nanmean(test_data)

    print(train_data.shape, train_label.shape, test_data.shape, test_label.shape)

    return train_data, train_label, test_data, test_label

# %%
train_data, train_label, test_data, test_label=read_bci_data()
train_data, train_label, test_data, test_label=read_bci_data()


train_data=torch.Tensor(train_data).cuda()
train_label=torch.Tensor(train_label).cuda()
test_data=torch.Tensor(test_data).cuda()
test_label=torch.Tensor(test_label).cuda()

train_dataset=Data.TensorDataset(train_data,train_label)
test_dataset=Data.TensorDataset(test_data,test_label)
# Out:
# (1080, 1, 2, 750) (1080,) (1080, 1, 2, 750) (1080,)
# (1080, 1, 2, 750) (1080,) (1080, 1, 2, 750) (1080,)

# %% [markdown]
# ### EEG

# %%
BATCH_SIZE=32
LR=1e-3
EPOCHS=200
loss_func=nn.CrossEntropyLoss()

train_loader=Data.DataLoader(dataset=train_dataset,batch_size=BATCH_SIZE,shuffle=True)
test_loader=Data.DataLoader(dataset=test_dataset,batch_size=BATCH_SIZE,shuffle=False)

# %%
model=EEGNET(nn.ReLU())
model.cuda()
optimizer=optim.Adam(model.parameters(),lr=LR)

lossValues=[]
accValues=[]
MaxAcc=0
for epoch in range(EPOCHS):
    model.train()
    for index,(x,y) in enumerate(train_loader):
        x=Variable(x)
        y=y.view(-1).long()
        _y=model(x)
        loss=loss_func(_y,y)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print("Epoch: [%3d], Loss: %.5f" %(epoch + 1, loss.data))
    lossValues.append(loss.data)
    
    model.eval()
    predicted=[]
    acc=0
    for index,(x,y) in enumerate(test_loader):
        x=Variable(x)
        _y=model(x)
        y=y.cpu().numpy()
        _y=_y.cpu().detach().numpy()
        predicts=(np.argmax(_y,axis=1)==y)
        acc+=np.count_nonzero(predicts)
    
    if (acc/test_data.shape[0])>MaxAcc:
        MaxAcc=acc/test_data.shape[0]
    accValues.append(acc/test_data.shape[0])
print(MaxAcc)
# Out:
# Epoch: [  1], Loss: 0.59615
# Epoch: [  2], Loss: 0.56374
# Epoch: [  3], Loss: 0.47502
# Epoch: [  4], Loss: 0.47729
# Epoch: [  5], Loss: 0.44569
# Epoch: [  6], Loss: 0.67211
# Epoch: [  7], Loss: 0.40128
# Epoch: [  8], Loss: 0.30419
# Epoch: [  9], Loss: 0.35928
# Epoch: [ 10], Loss: 0.39410
# Epoch: [ 11], Loss: 0.40467
# Epoch: [ 12], Loss: 0.54678
# Epoch: [ 13], Loss: 0.38442
# Epoch: [ 14], Loss: 0.34963
# Epoch: [ 15], Loss: 0.39749
# Epoch: [ 16], Loss: 0.36015
# Epoch: [ 17], Loss: 0.31359
# Epoch: [ 18], Loss: 0.23442
# Epoch: [ 19], Loss: 0.46682
# Epoch: [ 20], Loss: 0.38371
# Epoch: [ 21], Loss: 0.61568
# Epoch: [ 22], Loss: 0.11448
# Epoch: [ 23], Loss: 0.31008
# Epoch: [ 24], Loss: 0.21835
# Epoch: [ 25], Loss: 0.17747
# Epoch: [ 26], Loss: 0.27260
# Epoch: [ 27], Loss: 0.35808
# Epoch: [ 28], Loss: 0.40811
# Epoch: [ 29], Loss: 0.24541
# Epoch: [ 30], Loss: 0.22059
# Epoch: [ 31], Loss: 0.28558
# Epoch: [ 32], Loss: 0.27885
# Epoch: [ 33], Loss: 0.19866
# Epoch: [ 34], Loss: 0.22094
# Epoch: [ 35], Loss: 0.26277
# Epoch: [ 36], Loss: 0.31190
# Epoch: [ 37], Loss: 0.23666
# Epoch: [ 38], Loss: 0.17853
# Epoch: [ 39], Loss: 0.17762
# Epoch: [ 40], Loss: 0.19536
# Epoch: [ 41], Loss: 0.41813
# Epoch: [ 42], Loss: 0.24658
# Epoch: [ 43], Loss: 0.15817
# Epoch: [ 44], Loss: 0.20613
# Epoch: [ 45], Loss: 0.19038
# Epoch: [ 46], Loss: 0.12425
# Epoch: [ 47], Loss: 0.21002
# Epoch: [ 48], Loss: 0.28275
# Epoch: [ 49], Loss: 0.09432
# Epoch: [ 50], Loss: 0.25033
# Epoch: [ 51], Loss: 0.16851
# Epoch: [ 52], Loss: 0.08230
# Epoch: [ 53], Loss: 0.28292
# Epoch: [ 54], Loss: 0.39234
# Epoch: [ 55], Loss: 0.09017
# Epoch: [ 56], Loss: 0.04044
# Epoch: [ 57], Loss: 0.25504
# Epoch: [ 58], Loss: 0.16265
# Epoch: [ 59], Loss: 0.28489
# Epoch: [ 60], Loss: 0.06389
# Epoch: [ 61], Loss: 0.11954
# Epoch: [ 62], Loss: 0.16426
# Epoch: [ 63], Loss: 0.06477
# Epoch: [ 64], Loss: 0.06468
# Epoch: [ 65], Loss: 0.25696
# Epoch: [ 66], Loss: 0.33214
# Epoch: [ 67], Loss: 0.07177
# Epoch: [ 68], Loss: 0.06803
# Epoch: [ 69], Loss: 0.20569
# Epoch: [ 70], Loss: 0.16246
# Epoch: [ 71], Loss: 0.10785
# Epoch: [ 72], Loss: 0.13336
# Epoch: [ 73], Loss: 0.13756
# Epoch: [ 74], Loss: 0.19673
# Epoch: [ 75], Loss: 0.06857
# Epoch: [ 76], Loss: 0.05027
# Epoch: [ 77], Loss: 0.21555
# Epoch: [ 78], Loss: 0.18596
# Epoch: [ 79], Loss: 0.21451
# Epoch: [ 80], Loss: 0.15183
# Epoch: [ 81], Loss: 0.11855
# Epoch: [ 82], Loss: 0.07714
# Epoch: [ 83], Loss: 0.10343
# Epoch: [ 84], Loss: 0.02980
# Epoch: [ 85], Loss: 0.18003
# Epoch: [ 86], Loss: 0.19590
# Epoch: [ 87], Loss: 0.14596
# Epoch: [ 88], Loss: 0.15046
# Epoch: [ 89], Loss: 0.28908
# Epoch: [ 90], Loss: 0.02313
# Epoch: [ 91], Loss: 0.27443
# Epoch: [ 92], Loss: 0.14522
# Epoch: [ 93], Loss: 0.17694
# Epoch: [ 94], Loss: 0.09252
# Epoch: [ 95], Loss: 0.22531
# Epoch: [ 96], Loss: 0.33566
# Epoch: [ 97], Loss: 0.08480
# Epoch: [177], Loss: 0.01558
# Epoch: [178], Loss: 0.07595
# Epoch: [179], Loss: 0.03957
# Epoch: [180], Loss: 0.11280
# Epoch: [181], Loss: 0.02299
# Epoch: [182], Loss: 0.07986
# Epoch: [183], Loss: 0.01604
# Epoch: [184], Loss: 0.06136
# Epoch: [185], Loss: 0.05130
# Epoch: [186], Loss: 0.18748
# Epoch: [187], Loss: 0.25182
# Epoch: [188], Loss: 0.02967
# Epoch: [189], Loss: 0.09829
# Epoch: [190], Loss: 0.12571
# Epoch: [191], Loss: 0.06925
# Epoch: [192], Loss: 0.02956
# Epoch: [193], Loss: 0.05309
# Epoch: [194], Loss: 0.09636
# Epoch: [195], Loss: 0.08022
# Epoch: [196], Loss: 0.11538
# Epoch: [197], Loss: 0.12645
# Epoch: [198], Loss: 0.12920
# Epoch: [199], Loss: 0.04902
# Epoch: [200], Loss: 0.14686
# 0.8759259259259259

# %%
plt.plot(lossValues)
plt.show()
plt.plot(accValues)
plt.show()

# %%
model=EEGNET()
model.cuda()
optimizer=optim.Adam(model.parameters(),lr=LR)

lossValues=[]
accValues=[]
for epoch in range(EPOCHS):
    model.train()
    for index,(x,y) in enumerate(train_loader):
        x=Variable(x)
        y=y.view(-1).long()
        _y=model(x)
        loss=loss_func(_y,y)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print("Epoch: [%3d], Loss: %.5f" %(epoch + 1, loss.data))
    lossValues.append(loss.data)
    
    model.eval()
    predicted=[]
    acc=0
    for index,(x,y) in enumerate(test_loader):
        x=Variable(x)
        _y=model(x)
        y=y.cpu().numpy()
        _y=_y.cpu().detach().numpy()
        predicts=(np.argmax(_y,axis=1)==y)
        acc+=np.count_nonzero(predicts)
    accValues.append(acc/test_data.shape[0])
# Out:
# Epoch: [  1], Loss: 0.69875
# Epoch: [  2], Loss: 0.64372
# Epoch: [  3], Loss: 0.61595
# Epoch: [  4], Loss: 0.61292
# Epoch: [  5], Loss: 0.59213
# Epoch: [  6], Loss: 0.60540
# Epoch: [  7], Loss: 0.59836
# Epoch: [  8], Loss: 0.60093
# Epoch: [  9], Loss: 0.58853
# Epoch: [ 10], Loss: 0.60160
# Epoch: [ 11], Loss: 0.60967
# Epoch: [ 12], Loss: 0.59514
# Epoch: [ 13], Loss: 0.55399
# Epoch: [ 14], Loss: 0.52632
# Epoch: [ 15], Loss: 0.52225
# Epoch: [ 16], Loss: 0.52862
# Epoch: [ 17], Loss: 0.59393
# Epoch: [ 18], Loss: 0.54648
# Epoch: [ 19], Loss: 0.53940
# Epoch: [ 20], Loss: 0.54874
# Epoch: [ 21], Loss: 0.51880
# Epoch: [ 22], Loss: 0.49906
# Epoch: [ 23], Loss: 0.52128
# Epoch: [ 24], Loss: 0.48280
# Epoch: [ 25], Loss: 0.47220
# Epoch: [ 26], Loss: 0.47219
# Epoch: [ 27], Loss: 0.49867
# Epoch: [ 28], Loss: 0.55232
# Epoch: [ 29], Loss: 0.48757
# Epoch: [ 30], Loss: 0.43826
# Epoch: [ 31], Loss: 0.50716
# Epoch: [ 32], Loss: 0.43579
# Epoch: [ 33], Loss: 0.43670
# Epoch: [ 34], Loss: 0.37980
# Epoch: [ 35], Loss: 0.41818
# Epoch: [ 36], Loss: 0.40129
# Epoch: [ 37], Loss: 0.33865
# Epoch: [ 38], Loss: 0.39223
# Epoch: [ 39], Loss: 0.39124
# Epoch: [ 40], Loss: 0.36471
# Epoch: [ 41], Loss: 0.37539
# Epoch: [ 42], Loss: 0.37542
# Epoch: [ 43], Loss: 0.34246
# Epoch: [ 44], Loss: 0.37738
# Epoch: [ 45], Loss: 0.35050
# Epoch: [ 46], Loss: 0.33279
# Epoch: [ 47], Loss: 0.33093
# Epoch: [ 48], Loss: 0.30105
# Epoch: [ 49], Loss: 0.36821
# Epoch: [ 50], Loss: 0.24617
# Epoch: [ 51], Loss: 0.35509
# Epoch: [ 52], Loss: 0.32115
# Epoch: [ 53], Loss: 0.29348
# Epoch: [ 54], Loss: 0.33923
# Epoch: [ 55], Loss: 0.26263
# Epoch: [ 56], Loss: 0.31675
# Epoch: [ 57], Loss: 0.24954
# Epoch: [ 58], Loss: 0.26927
# Epoch: [ 59], Loss: 0.29918
# Epoch: [ 60], Loss: 0.25870
# Epoch: [ 61], Loss: 0.26798
# Epoch: [ 62], Loss: 0.25649
# Epoch: [ 63], Loss: 0.25117
# Epoch: [ 64], Loss: 0.29447
# Epoch: [ 65], Loss: 0.33281
# Epoch: [ 66], Loss: 0.29598
# Epoch: [ 67], Loss: 0.21820
# Epoch: [ 68], Loss: 0.26379
# Epoch: [ 69], Loss: 0.25981
# Epoch: [ 70], Loss: 0.26023
# Epoch: [ 71], Loss: 0.24743
# Epoch: [ 72], Loss: 0.20148
# Epoch: [ 73], Loss: 0.24747
# Epoch: [ 74], Loss: 0.28827
# Epoch: [ 75], Loss: 0.21300
# Epoch: [ 76], Loss: 0.22520
# Epoch: [ 77], Loss: 0.19900
# Epoch: [ 78], Loss: 0.22051
# Epoch: [ 79], Loss: 0.26081
# Epoch: [ 80], Loss: 0.29341
# Epoch: [ 81], Loss: 0.20748
# Epoch: [ 82], Loss: 0.20102
# Epoch: [ 83], Loss: 0.21708
# Epoch: [ 84], Loss: 0.20096
# Epoch: [ 85], Loss: 0.25840
# Epoch: [ 86], Loss: 0.27331
# Epoch: [ 87], Loss: 0.27184
# Epoch: [ 88], Loss: 0.21237
# Epoch: [ 89], Loss: 0.27633
# Epoch: [ 90], Loss: 0.18799
# Epoch: [ 91], Loss: 0.26882
# Epoch: [ 92], Loss: 0.18553
# Epoch: [ 93], Loss: 0.18658
# Epoch: [ 94], Loss: 0.22566
# Epoch: [ 95], Loss: 0.29137
# Epoch: [ 96], Loss: 0.20670
# Epoch: [ 97], Loss: 0.22454
# Epoch: [ 98], Loss: 0.25583
# Epoch: [ 99], Loss: 0.24844
# Epoch: [100], Loss: 0.21301
# Epoch: [101], Loss: 0.28168
# Epoch: [102], Loss: 0.25002
# Epoch: [103], Loss: 0.24271
# Epoch: [263], Loss: 0.07660
# Epoch: [264], Loss: 0.14575
# Epoch: [265], Loss: 0.08703
# Epoch: [266], Loss: 0.10182
# Epoch: [267], Loss: 0.16990
# Epoch: [268], Loss: 0.07759
# Epoch: [269], Loss: 0.06675
# Epoch: [270], Loss: 0.11339
# Epoch: [271], Loss: 0.08251
# Epoch: [272], Loss: 0.15608
# Epoch: [273], Loss: 0.13081
# Epoch: [274], Loss: 0.08520
# Epoch: [275], Loss: 0.15294
# Epoch: [276], Loss: 0.16062
# Epoch: [277], Loss: 0.13947
# Epoch: [278], Loss: 0.13254
# Epoch: [279], Loss: 0.12693
# Epoch: [280], Loss: 0.09204
# Epoch: [281], Loss: 0.10878
# Epoch: [282], Loss: 0.05440
# Epoch: [283], Loss: 0.13935
# Epoch: [284], Loss: 0.11917
# Epoch: [285], Loss: 0.05428
# Epoch: [286], Loss: 0.18028
# Epoch: [287], Loss: 0.12017
# Epoch: [288], Loss: 0.07269
# Epoch: [289], Loss: 0.06446
# Epoch: [290], Loss: 0.09565
# Epoch: [291], Loss: 0.07846
# Epoch: [292], Loss: 0.07104
# Epoch: [293], Loss: 0.05835
# Epoch: [294], Loss: 0.14183
# Epoch: [295], Loss: 0.11842
# Epoch: [296], Loss: 0.04657
# Epoch: [297], Loss: 0.10357
# Epoch: [298], Loss: 0.06761
# Epoch: [299], Loss: 0.08429
# Epoch: [300], Loss: 0.08461

# %%
plt.plot(lossValues)
plt.show()
plt.plot(accValues)
plt.show()

# %%
model=EEGNET()
model.cuda()
optimizer=optim.Adam(model.parameters(),lr=LR)

lossValues=[]
accValues=[]
for epoch in range(EPOCHS):
    model.train()
    for index,(x,y) in enumerate(train_loader):
        x=Variable(x)
        y=y.view(-1).long()
        _y=model(x)
        loss=loss_func(_y,y)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print("Epoch: [%3d], Loss: %.5f" %(epoch + 1, loss.data))
    lossValues.append(loss.data)
    
    model.eval()
    predicted=[]
    acc=0
    for index,(x,y) in enumerate(test_loader):
        x=Variable(x)
        _y=model(x)
        y=y.cpu().numpy()
        _y=_y.cpu().detach().numpy()
        predicts=(np.argmax(_y,axis=1)==y)
        acc+=np.count_nonzero(predicts)
    accValues.append(acc/test_data.shape[0])
# Out:
# Epoch: [  1], Loss: 0.69207
# Epoch: [  2], Loss: 0.67275
# Epoch: [  3], Loss: 0.61840
# Epoch: [  4], Loss: 0.58440
# Epoch: [  5], Loss: 0.58923
# Epoch: [  6], Loss: 0.55432
# Epoch: [  7], Loss: 0.54552
# Epoch: [  8], Loss: 0.51350
# Epoch: [  9], Loss: 0.55678
# Epoch: [ 10], Loss: 0.52439
# Epoch: [ 11], Loss: 0.48820
# Epoch: [ 12], Loss: 0.47131
# Epoch: [ 13], Loss: 0.46806
# Epoch: [ 14], Loss: 0.46920
# Epoch: [ 15], Loss: 0.45389
# Epoch: [ 16], Loss: 0.47976
# Epoch: [ 17], Loss: 0.41442
# Epoch: [ 18], Loss: 0.36596
# Epoch: [ 19], Loss: 0.34961
# Epoch: [ 20], Loss: 0.43076
# Epoch: [ 21], Loss: 0.31448
# Epoch: [ 22], Loss: 0.27960
# Epoch: [ 23], Loss: 0.35670
# Epoch: [ 24], Loss: 0.31499
# Epoch: [ 25], Loss: 0.32029
# Epoch: [ 26], Loss: 0.31816
# Epoch: [ 27], Loss: 0.38030
# Epoch: [ 28], Loss: 0.23690
# Epoch: [ 29], Loss: 0.34734
# Epoch: [ 30], Loss: 0.28254
# Epoch: [ 31], Loss: 0.24993
# Epoch: [ 32], Loss: 0.32194
# Epoch: [ 33], Loss: 0.29524
# Epoch: [ 34], Loss: 0.24454
# Epoch: [ 35], Loss: 0.28089
# Epoch: [ 36], Loss: 0.26272
# Epoch: [ 37], Loss: 0.25058
# Epoch: [ 38], Loss: 0.25366
# Epoch: [ 39], Loss: 0.24328
# Epoch: [ 40], Loss: 0.20061
# Epoch: [ 41], Loss: 0.23485
# Epoch: [ 42], Loss: 0.17120
# Epoch: [ 43], Loss: 0.14425
# Epoch: [ 44], Loss: 0.21855
# Epoch: [ 45], Loss: 0.17261
# Epoch: [ 46], Loss: 0.16404
# Epoch: [ 47], Loss: 0.17896
# Epoch: [ 48], Loss: 0.18254
# Epoch: [ 49], Loss: 0.20865
# Epoch: [ 50], Loss: 0.19259
# Epoch: [ 51], Loss: 0.14986
# Epoch: [ 52], Loss: 0.22096
# Epoch: [ 53], Loss: 0.19583
# Epoch: [ 54], Loss: 0.13915
# Epoch: [ 55], Loss: 0.22629
# Epoch: [ 56], Loss: 0.14776
# Epoch: [ 57], Loss: 0.16615
# Epoch: [ 58], Loss: 0.19505
# Epoch: [ 59], Loss: 0.18057
# Epoch: [ 60], Loss: 0.14910
# Epoch: [ 61], Loss: 0.13062
# Epoch: [ 62], Loss: 0.14936
# Epoch: [ 63], Loss: 0.20759
# Epoch: [ 64], Loss: 0.12562
# Epoch: [ 65], Loss: 0.13513
# Epoch: [ 66], Loss: 0.14871
# Epoch: [ 67], Loss: 0.15004
# Epoch: [ 68], Loss: 0.11038
# Epoch: [ 69], Loss: 0.16656
# Epoch: [ 70], Loss: 0.15135
# Epoch: [ 71], Loss: 0.10082
# Epoch: [ 72], Loss: 0.13903
# Epoch: [ 73], Loss: 0.09122
# Epoch: [ 74], Loss: 0.12848
# Epoch: [ 75], Loss: 0.12998
# Epoch: [ 76], Loss: 0.13885
# Epoch: [ 77], Loss: 0.18235
# Epoch: [ 78], Loss: 0.16433
# Epoch: [ 79], Loss: 0.10136
# Epoch: [ 80], Loss: 0.12547
# Epoch: [ 81], Loss: 0.10201
# Epoch: [ 82], Loss: 0.12149
# Epoch: [ 83], Loss: 0.17138
# Epoch: [ 84], Loss: 0.15914
# Epoch: [ 85], Loss: 0.06582
# Epoch: [ 86], Loss: 0.09742
# Epoch: [ 87], Loss: 0.14278
# Epoch: [ 88], Loss: 0.07918
# Epoch: [ 89], Loss: 0.09166
# Epoch: [ 90], Loss: 0.14412
# Epoch: [ 91], Loss: 0.06409
# Epoch: [250], Loss: 0.09956
# Epoch: [251], Loss: 0.03475
# Epoch: [252], Loss: 0.05998
# Epoch: [253], Loss: 0.02163
# Epoch: [254], Loss: 0.08801
# Epoch: [255], Loss: 0.01970
# Epoch: [256], Loss: 0.04310
# Epoch: [257], Loss: 0.02845
# Epoch: [258], Loss: 0.04400
# Epoch: [259], Loss: 0.02742
# Epoch: [260], Loss: 0.05831
# Epoch: [261], Loss: 0.02883
# Epoch: [262], Loss: 0.04106
# Epoch: [263], Loss: 0.06689
# Epoch: [264], Loss: 0.09644
# Epoch: [265], Loss: 0.02236
# Epoch: [266], Loss: 0.04629
# Epoch: [267], Loss: 0.06872
# Epoch: [268], Loss: 0.05049
# Epoch: [269], Loss: 0.05029
# Epoch: [270], Loss: 0.04987
# Epoch: [271], Loss: 0.02243
# Epoch: [272], Loss: 0.05778
# Epoch: [273], Loss: 0.09777
# Epoch: [274], Loss: 0.02368
# Epoch: [275], Loss: 0.09339
# Epoch: [276], Loss: 0.07008
# Epoch: [277], Loss: 0.04239
# Epoch: [278], Loss: 0.01764
# Epoch: [279], Loss: 0.02125
# Epoch: [280], Loss: 0.01458
# Epoch: [281], Loss: 0.03725
# Epoch: [282], Loss: 0.02055
# Epoch: [283], Loss: 0.01224
# Epoch: [284], Loss: 0.01375
# Epoch: [285], Loss: 0.05306
# Epoch: [286], Loss: 0.00863
# Epoch: [287], Loss: 0.11586
# Epoch: [288], Loss: 0.02111
# Epoch: [289], Loss: 0.06905
# Epoch: [290], Loss: 0.08122
# Epoch: [291], Loss: 0.01048
# Epoch: [292], Loss: 0.05745
# Epoch: [293], Loss: 0.01382
# Epoch: [294], Loss: 0.00761
# Epoch: [295], Loss: 0.00957
# Epoch: [296], Loss: 0.01556
# Epoch: [297], Loss: 0.02989
# Epoch: [298], Loss: 0.09259
# Epoch: [299], Loss: 0.10326
# Epoch: [300], Loss: 0.05218

# %%
plt.plot(lossValues)
plt.show()
plt.plot(accValues)
plt.show()

# %% [markdown]
# ### DeepConvNet

# %%
BATCH_SIZE=32
LR=5e-4
EPOCHS=300
loss_func=nn.CrossEntropyLoss()

train_loader=Data.DataLoader(dataset=train_dataset,batch_size=BATCH_SIZE,shuffle=True)
test_loader=Data.DataLoader(dataset=test_dataset,batch_size=BATCH_SIZE,shuffle=False)

# %%
model=DeepConvNet(nn.LeakyReLU())
model.cuda()
optimizer=optim.RMSprop(model.parameters(),lr=LR)

lossValues=[]
accValues=[]
MaxAcc=0
for epoch in range(EPOCHS):
    model.train()
    for index,(x,y) in enumerate(train_loader):
        x=Variable(x)
        y=y.view(-1).long()
        _y=model(x)
        loss=loss_func(_y,y)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print("Epoch: [%3d], Loss: %.5f" %(epoch + 1, loss.data))
    lossValues.append(loss.data)
    
    model.eval()
    predicted=[]
    acc=0
    for index,(x,y) in enumerate(test_loader):
        x=Variable(x)
        _y=model(x)
        y=y.cpu().numpy()
        _y=_y.cpu().detach().numpy()
        predicts=(np.argmax(_y,axis=1)==y)
        acc+=np.count_nonzero(predicts)
    
    if (acc/test_data.shape[0])>MaxAcc:
        MaxAcc=acc/test_data.shape[0]
    accValues.append(acc/test_data.shape[0])
print(MaxAcc)
# Out:
# Epoch: [  1], Loss: 0.79601
# Epoch: [  2], Loss: 0.50907
# Epoch: [  3], Loss: 0.60529
# Epoch: [  4], Loss: 0.67601
# Epoch: [  5], Loss: 0.54364
# Epoch: [  6], Loss: 0.56731
# Epoch: [  7], Loss: 0.59351
# Epoch: [  8], Loss: 0.44530
# Epoch: [  9], Loss: 0.58879
# Epoch: [ 10], Loss: 0.64035
# Epoch: [ 11], Loss: 0.40066
# Epoch: [ 12], Loss: 0.48427
# Epoch: [ 13], Loss: 0.38457
# Epoch: [ 14], Loss: 0.61170
# Epoch: [ 15], Loss: 0.84275
# Epoch: [ 16], Loss: 0.49774
# Epoch: [ 17], Loss: 0.50144
# Epoch: [ 18], Loss: 0.37137
# Epoch: [ 19], Loss: 0.33341
# Epoch: [ 20], Loss: 0.65265
# Epoch: [ 21], Loss: 0.41801
# Epoch: [ 22], Loss: 0.37114
# Epoch: [ 23], Loss: 0.43334
# Epoch: [ 24], Loss: 0.58010
# Epoch: [ 25], Loss: 0.35266
# Epoch: [ 26], Loss: 0.37610
# Epoch: [ 27], Loss: 0.50264
# Epoch: [ 28], Loss: 0.45088
# Epoch: [ 29], Loss: 0.44534
# Epoch: [ 30], Loss: 0.62604
# Epoch: [ 31], Loss: 0.51726
# Epoch: [ 32], Loss: 0.42364
# Epoch: [ 33], Loss: 0.24869
# Epoch: [ 34], Loss: 0.30758
# Epoch: [ 35], Loss: 0.29959
# Epoch: [ 36], Loss: 0.52338
# Epoch: [ 37], Loss: 0.67630
# Epoch: [ 38], Loss: 0.48579
# Epoch: [ 39], Loss: 0.38802
# Epoch: [ 40], Loss: 0.46713
# Epoch: [ 41], Loss: 0.60371
# Epoch: [ 42], Loss: 0.31663
# Epoch: [ 43], Loss: 0.31783
# Epoch: [ 44], Loss: 0.23894
# Epoch: [ 45], Loss: 0.44822
# Epoch: [ 46], Loss: 0.68458
# Epoch: [ 47], Loss: 0.33098
# Epoch: [ 48], Loss: 0.37919
# Epoch: [ 49], Loss: 0.26706
# Epoch: [ 50], Loss: 0.31707
# Epoch: [ 51], Loss: 0.30096
# Epoch: [ 52], Loss: 0.41583
# Epoch: [ 53], Loss: 0.37496
# Epoch: [ 54], Loss: 0.51813
# Epoch: [ 55], Loss: 0.20167
# Epoch: [ 56], Loss: 0.45785
# Epoch: [ 57], Loss: 0.37797
# Epoch: [ 58], Loss: 0.20083
# Epoch: [ 59], Loss: 0.42606
# Epoch: [ 60], Loss: 0.28109
# Epoch: [ 61], Loss: 0.50408
# Epoch: [ 62], Loss: 0.26040
# Epoch: [ 63], Loss: 0.34103
# Epoch: [ 64], Loss: 0.34562
# Epoch: [ 65], Loss: 0.40103
# Epoch: [ 66], Loss: 0.30995
# Epoch: [ 67], Loss: 0.46708
# Epoch: [ 68], Loss: 0.36378
# Epoch: [ 69], Loss: 0.18548
# Epoch: [ 70], Loss: 0.31795
# Epoch: [ 71], Loss: 0.49121
# Epoch: [ 72], Loss: 0.66231
# Epoch: [ 73], Loss: 0.24366
# Epoch: [ 74], Loss: 0.24563
# Epoch: [ 75], Loss: 0.25987
# Epoch: [ 76], Loss: 0.31728
# Epoch: [ 77], Loss: 0.41149
# Epoch: [ 78], Loss: 0.47954
# Epoch: [ 79], Loss: 0.30097
# Epoch: [ 80], Loss: 0.13897
# Epoch: [ 81], Loss: 0.50261
# Epoch: [ 82], Loss: 0.38260
# Epoch: [ 83], Loss: 0.23946
# Epoch: [ 84], Loss: 0.15433
# Epoch: [ 85], Loss: 0.12284
# Epoch: [ 86], Loss: 0.17926
# Epoch: [ 87], Loss: 0.29916
# Epoch: [ 88], Loss: 0.17895
# Epoch: [ 89], Loss: 0.63037
# Epoch: [ 90], Loss: 0.20430
# Epoch: [ 91], Loss: 0.19863
# Epoch: [ 92], Loss: 0.20372
# Epoch: [ 93], Loss: 0.28455
# Epoch: [ 94], Loss: 0.53289
# Epoch: [ 95], Loss: 0.25158
# Epoch: [ 96], Loss: 0.45402
# Epoch: [ 97], Loss: 0.24058
# Epoch: [ 98], Loss: 0.15136
# Epoch: [ 99], Loss: 0.43259
# Epoch: [100], Loss: 0.33749
# Epoch: [101], Loss: 0.13830
# Epoch: [102], Loss: 0.32979
# Epoch: [103], Loss: 0.32495
# Epoch: [104], Loss: 0.45148
# Epoch: [105], Loss: 0.24816
# Epoch: [106], Loss: 0.37527
# Epoch: [107], Loss: 0.17709
# Epoch: [108], Loss: 0.46860
# Epoch: [109], Loss: 0.18286
# Epoch: [110], Loss: 0.28100
# Epoch: [111], Loss: 0.15276
# Epoch: [112], Loss: 0.34791
# Epoch: [113], Loss: 0.42353
# Epoch: [114], Loss: 0.07554
# Epoch: [115], Loss: 0.13982
# Epoch: [116], Loss: 0.23043
# Epoch: [117], Loss: 0.43481
# Epoch: [118], Loss: 0.20715
# Epoch: [119], Loss: 0.15913
# Epoch: [120], Loss: 0.25739
# Epoch: [121], Loss: 0.16406
# Epoch: [122], Loss: 0.27587
# Epoch: [123], Loss: 0.22704
# Epoch: [124], Loss: 0.21790
# Epoch: [125], Loss: 0.38529
# Epoch: [126], Loss: 0.22964
# Epoch: [127], Loss: 0.11526
# Epoch: [128], Loss: 0.26947
# Epoch: [129], Loss: 0.25921
# Epoch: [130], Loss: 0.19103
# Epoch: [131], Loss: 0.11072
# Epoch: [132], Loss: 0.12880
# Epoch: [133], Loss: 0.09690
# Epoch: [134], Loss: 0.24658
# Epoch: [135], Loss: 0.14663
# Epoch: [136], Loss: 0.11730
# Epoch: [137], Loss: 0.14356
# Epoch: [138], Loss: 0.44968
# Epoch: [139], Loss: 0.47594
# Epoch: [140], Loss: 0.11534
# Epoch: [141], Loss: 0.33685
# Epoch: [142], Loss: 0.26115
# Epoch: [143], Loss: 0.08643
# Epoch: [224], Loss: 0.01831
# Epoch: [225], Loss: 0.18004
# Epoch: [226], Loss: 0.03695
# Epoch: [227], Loss: 0.12585
# Epoch: [228], Loss: 0.25778
# Epoch: [229], Loss: 0.24783
# Epoch: [230], Loss: 0.13109
# Epoch: [231], Loss: 0.18442
# Epoch: [232], Loss: 0.20656
# Epoch: [233], Loss: 0.17597
# Epoch: [234], Loss: 0.18837
# Epoch: [235], Loss: 0.23357
# Epoch: [236], Loss: 0.04443
# Epoch: [237], Loss: 0.09737
# Epoch: [238], Loss: 0.23147
# Epoch: [239], Loss: 0.06704
# Epoch: [240], Loss: 0.03803
# Epoch: [241], Loss: 0.11364
# Epoch: [242], Loss: 0.07943
# Epoch: [243], Loss: 0.11872
# Epoch: [244], Loss: 0.05543
# Epoch: [245], Loss: 0.09330
# Epoch: [246], Loss: 0.07913
# Epoch: [247], Loss: 0.02898
# Epoch: [248], Loss: 0.12970
# Epoch: [249], Loss: 0.12477
# Epoch: [250], Loss: 0.16912
# Epoch: [251], Loss: 0.06668
# Epoch: [252], Loss: 0.18600
# Epoch: [253], Loss: 0.08905
# Epoch: [254], Loss: 0.39972
# Epoch: [255], Loss: 0.18472
# Epoch: [256], Loss: 0.30791
# Epoch: [257], Loss: 0.23604
# Epoch: [258], Loss: 0.10079
# Epoch: [259], Loss: 0.07939
# Epoch: [260], Loss: 0.10574
# Epoch: [261], Loss: 0.16790
# Epoch: [262], Loss: 0.20459
# Epoch: [263], Loss: 0.04382
# Epoch: [264], Loss: 0.04854
# Epoch: [265], Loss: 0.03538
# Epoch: [266], Loss: 0.05543
# Epoch: [267], Loss: 0.12917
# Epoch: [268], Loss: 0.08820
# Epoch: [269], Loss: 0.02983
# Epoch: [270], Loss: 0.18181
# Epoch: [271], Loss: 0.06948
# Epoch: [272], Loss: 0.11394
# Epoch: [273], Loss: 0.05894
# Epoch: [274], Loss: 0.04731
# Epoch: [275], Loss: 0.24212
# Epoch: [276], Loss: 0.22025
# Epoch: [277], Loss: 0.17323
# Epoch: [278], Loss: 0.15779
# Epoch: [279], Loss: 0.15878
# Epoch: [280], Loss: 0.09254
# Epoch: [281], Loss: 0.08993
# Epoch: [282], Loss: 0.23297
# Epoch: [283], Loss: 0.16784
# Epoch: [284], Loss: 0.05622
# Epoch: [285], Loss: 0.13527
# Epoch: [286], Loss: 0.10488
# Epoch: [287], Loss: 0.03461
# Epoch: [288], Loss: 0.03971
# Epoch: [289], Loss: 0.12352
# Epoch: [290], Loss: 0.09563
# Epoch: [291], Loss: 0.20238
# Epoch: [292], Loss: 0.27332
# Epoch: [293], Loss: 0.06052
# Epoch: [294], Loss: 0.08360
# Epoch: [295], Loss: 0.27083
# Epoch: [296], Loss: 0.10859
# Epoch: [297], Loss: 0.13629
# Epoch: [298], Loss: 0.07463
# Epoch: [299], Loss: 0.28916
# Epoch: [300], Loss: 0.13404
# 0.825

# %%
plt.plot(lossValues)
plt.show()
plt.plot(accValues)
plt.show()
